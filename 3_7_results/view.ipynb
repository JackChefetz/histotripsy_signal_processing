# %%
import scipy.io
import pandas as pd

file = scipy.io.loadmat('datat5.mat')
file
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Mar  7 13:59:51 2025',
#  '__version__': '1.0',
#  '__globals__': [],
#  'ttp_dict': array([[MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                               [         2],
#                               [         1],
#                               [         1],
#                               [         1],
#                               [         1]], dtype=uint32))            ],
#                       dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]),
#          array(['Error: poor fit'], dtype='<U15')],
#         [MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                               [         2],
#                               [         1],
#                               [         1],
#                               [         2],
#                               [         1]], dtype=uint32))            ],
# ...
